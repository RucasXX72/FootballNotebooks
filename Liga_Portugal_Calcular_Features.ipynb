# %% [markdown]
# Fazer imports

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mtl

# %% [markdown]
# Definição de constantes

# %%
MAIN_PATH = '/content/drive/MyDrive/'
CLEAN_PATH = MAIN_PATH + 'Data_Football/Liga_Portugal/Clean/'

# %% [markdown]
# Invocar notebooks de funções

# %%
functions_path = MAIN_PATH + 'Colab Notebooks/Bet_Functions.ipynb'

# %run '{functions_path}'

# %% [markdown]
# Initi plot

# %%
mtl.rcParams['axes.grid'] = 'True'
mtl.rcParams['axes.spines.top'] = 'False'
mtl.rcParams['axes.spines.right'] = 'False'
mtl.rcParams['xtick.labelsize'] = 20
mtl.rcParams['ytick.labelsize'] = 20

# %% [markdown]
# incializar dataframe dp_lp (liga portugal)

# %%
df_lp= pd.read_csv(CLEAN_PATH + 'Liga_Portugal_2022_23_clean.csv')

# %% [markdown]
# Criar lista com todas as equipas

# %%
home_teams = df_lp['HomeTeam'].unique()
away_teams = df_lp['AwayTeam'].unique()

all_teams = list(set(np.append(home_teams, away_teams)))

print(all_teams)
# Out:
# ['FAMALICAO', 'PORTIMONENSE', 'AROUCA', 'BOAVISTA', 'PORTO', 'SPLISBON', 'SPBRAGA', 'CHAVES', 'CASAPIA', 'GUIMARAES', 'RIOAVE', 'GILVICENTE', 'VIZELA', 'MARITIMO', 'ESTORIL', 'BENFICA', 'SANTACLARA', 'PACOSFERREIRA']

# %% [markdown]
# Calcular feature para todos os clubes (usa função calc_feats() definida em Bet_Functions.ipynb

# %%
all_teams_stats = []

for team in all_teams:
  team_stats = calc_feats(df_lp, team)
  all_teams_stats.append(team_stats)

print(all_teams_stats)
# Out:
# [{'team': 'FAMALICAO', 'shots': 420, 'shots_ot': 120, 'shots_vs': 482, 'shots_ot_vs': 160, 'points': 46}, {'team': 'PORTIMONENSE', 'shots': 394, 'shots_ot': 119, 'shots_vs': 547, 'shots_ot_vs': 199, 'points': 38}, {'team': 'AROUCA', 'shots': 363, 'shots_ot': 126, 'shots_vs': 440, 'shots_ot_vs': 147, 'points': 50}, {'team': 'BOAVISTA', 'shots': 367, 'shots_ot': 116, 'shots_vs': 382, 'shots_ot_vs': 142, 'points': 39}, {'team': 'PORTO', 'shots': 508, 'shots_ot': 184, 'shots_vs': 291, 'shots_ot_vs': 81, 'points': 83}, {'team': 'SPLISBON', 'shots': 540, 'shots_ot': 198, 'shots_vs': 268, 'shots_ot_vs': 96, 'points': 71}, {'team': 'SPBRAGA', 'shots': 552, 'shots_ot': 223, 'shots_vs': 366, 'shots_ot_vs': 116, 'points': 77}, {'team': 'CHAVES', 'shots': 445, 'shots_ot': 143, 'shots_vs': 554, 'shots_ot_vs': 165, 'points': 42}, {'team': 'CASAPIA', 'shots': 379, 'shots_ot': 117, 'shots_vs': 461, 'shots_ot_vs': 150, 'points': 39}, {'team': 'GUIMARAES', 'shots': 392, 'shots_ot': 120, 'shots_vs': 401, 'shots_ot_vs': 124, 'points': 52}, {'team': 'RIOAVE', 'shots': 380, 'shots_ot': 123, 'shots_vs': 477, 'shots_ot_vs': 154, 'points': 36}, {'team': 'GILVICENTE', 'shots': 444, 'shots_ot': 145, 'shots_vs': 476, 'shots_ot_vs': 179, 'points': 35}, {'team': 'VIZELA', 'shots': 405, 'shots_ot': 154, 'shots_vs': 454, 'shots_ot_vs': 135, 'points': 41}, {'team': 'MARITIMO', 'shots': 465, 'shots_ot': 132, 'shots_vs': 466, 'shots_ot_vs': 167, 'points': 29}, {'team': 'ESTORIL', 'shots': 355, 'shots_ot': 112, 'shots_vs': 493, 'shots_ot_vs': 167, 'points': 38}, {'team': 'BENFICA', 'shots': 569, 'shots_ot': 208, 'shots_vs': 244, 'shots_ot_vs': 78, 'points': 85}, {'team': 'SANTACLARA', 'shots': 358, 'shots_ot': 119, 'shots_vs': 451, 'shots_ot_vs': 157, 'points': 23}, {'team': 'PACOSFERREIRA', 'shots': 390, 'shots_ot': 119, 'shots_vs': 473, 'shots_ot_vs': 161, 'points': 30}]

# %% [markdown]
# Gravar em disco

# %%
df_all_stats= pd.DataFrame(all_teams_stats)
df_all_stats.to_csv('/content/drive/MyDrive/Data_Football/Liga_Portugal/Stats/Liga_Portugal_Stats_2022_23.csv')
