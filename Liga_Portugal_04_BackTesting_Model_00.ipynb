# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Packages

# %%
import os
import pandas as pd
import numpy as np
import joblib
import math
import decimal
import matplotlib.pyplot as plt

# %%
MAIN_PATH = '/content/drive/MyDrive/'

# %% [markdown]
# Limpar dir de predicts

# %%
functions_path = MAIN_PATH + 'Colab Notebooks/Bet_Functions.ipynb'

# %run '{functions_path}'

# %% [markdown]
# Inicializar params e paths

# %%
param_league = 'Liga_Portugal'
param_league_short = 'lp'
param_season = '_2023_24'
param_final_flag = True
param_odd_bet_limit = 1.2
param_number_matches_week = 9
param_itera_jornada = 10
param_list_derby_teams = []
param_uniform_bet_size = False

main_league_path  = MAIN_PATH + 'Data_Football/{0}/'.format(param_league)

param_predicts_path = main_league_path + 'Predicts/Experiments'


raw_path = main_league_path + 'Raw/{0}{1}.csv'.format(param_league,param_season)
final_summary_path = main_league_path + 'Predicts/Summary{0}.csv'.format(param_season)

# %% [markdown]
# Apagar todos os ficheiro na pasta de predicts

# %%
delete_files_in_directory(param_predicts_path)
# Out:
# All files deleted successfully.

# %% [markdown]
# invocar generico

# %%
df_raw_test =pd.read_csv(raw_path)
number_matches = df_raw_test[df_raw_test.columns[0]].count()
numero_jornadas = math.ceil(number_matches/10)


while param_itera_jornada <= numero_jornadas:
  # %run '/content/drive/MyDrive/Colab Notebooks/Model_00_ETL_PREDICT_Generico.ipynb'
  param_itera_jornada = jornada + 1
# Out:
# in: /content/drive/MyDrive/Data_Football/Liga_Portugal/Predicts/Experiments/Summary_lp_2023_24.csv
# Jornada: 10
# total_funds_previousweek = 50.0
# bet_size = 2.5
# total win provisory = -2.15
# total fundos provisory = 47.85
# in: /content/drive/MyDrive/Data_Football/Liga_Portugal/Predicts/Experiments/Summary_lp_2023_24.csv
# Jornada: 11
# total_funds_previousweek = 47.85
# bet_size = 2.0
# total win provisory = 11.52
# total fundos provisory = 59.37
# in: /content/drive/MyDrive/Data_Football/Liga_Portugal/Predicts/Experiments/Summary_lp_2023_24.csv
# Jornada: 12
# total_funds_previousweek = 59.37
# bet_size = 2.5
# total win provisory = 4.1
# total fundos provisory = 63.47
# in: /content/drive/MyDrive/Data_Football/Liga_Portugal/Predicts/Experiments/Summary_lp_2023_24.csv
# Jornada: 13
# total_funds_previousweek = 63.47
# bet_size = 3.0
# total win provisory = 8.67
# total fundos provisory = 72.14
# in: /content/drive/MyDrive/Data_Football/Liga_Portugal/Predicts/Experiments/Summary_lp_2023_24.csv
# Jornada: 14
# total_funds_previousweek = 72.14
# bet_size = 3.5
# total win provisory = 1.33
# total fundos provisory = 73.47
# in: /content/drive/MyDrive/Data_Football/Liga_Portugal/Predicts/Experiments/Summary_lp_2023_24.csv
# Jornada: 15
# total_funds_previousweek = 73.47
# bet_size = 3.5
# total win provisory = 21.0
# total fundos provisory = 94.47
# in: /content/drive/MyDrive/Data_Football/Liga_Portugal/Predicts/Experiments/Summary_lp_2023_24.csv
# Jornada: 16
# total_funds_previousweek = 94.47
# bet_size = 4.5
# total win provisory = -4.05
# total fundos provisory = 90.42

# %% [markdown]
# Executar gráficos

# %%
# %run '/content/drive/MyDrive/Colab Notebooks/Generic_Graphs.ipynb'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# summary_path =/content/drive/MyDrive/Data_Football/Liga_Portugal/Predicts/Experiments/Summary_lp_2023_24.csv

# %% [markdown]
# Reset dos parametros

# %%
param_league = 'Bundesliga'
param_league_short = 'bd'
param_season = '_2023_24'
param_final_flag = True
param_odd_bet_limit = 1.2
param_number_matches_week = 9
param_itera_jornada = 10
