# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Packages

# %%
import os
import pandas as pd
import numpy as np
import joblib
import math
import decimal
import matplotlib.pyplot as plt

# %%
MAIN_PATH = '/content/drive/MyDrive/'

# %% [markdown]
# Limpar dir de predicts

# %%
functions_path = MAIN_PATH + 'Colab Notebooks/Bet_Functions.ipynb'

# %run '{functions_path}'

# %% [markdown]
# Inicializar params e paths

# %%
param_league = 'Premiere_League'
param_league_short = 'epl'
param_season = '_2023_24'
param_final_flag = True
param_odd_bet_limit = 1.2
param_number_matches_week = 10
param_itera_jornada = 2

param_list_derby_teams = []
param_uniform_bet_size = True

main_league_path  = MAIN_PATH + 'Data_Football/{0}/'.format(param_league)

param_predicts_path = main_league_path + 'Predicts/Experiments'


raw_path = main_league_path + 'Raw/{0}{1}.csv'.format(param_league,param_season)
final_summary_path = main_league_path + 'Predicts/Summary{0}.csv'.format(param_season)

# %% [markdown]
# Apagar todos os ficheiro na pasta de predicts

# %%
delete_files_in_directory(param_predicts_path)
# Out:
# All files deleted successfully.

# %% [markdown]
# invocar generico

# %%
df_raw_test =pd.read_csv(raw_path)
number_matches = df_raw_test[df_raw_test.columns[0]].count()
numero_jornadas = math.ceil(number_matches/10)


while param_itera_jornada <= numero_jornadas:
  # %run '/content/drive/MyDrive/Colab Notebooks/Model_00_ETL_PREDICT_Generico.ipynb'
  param_itera_jornada = jornada + 1
# Out:
# in: /content/drive/MyDrive/Data_Football/Premiere_League/Predicts/Experiments/Summary_epl_2023_24.csv
# Jornada: 2
# total_funds_previousweek = 50.0
# bet_size = 2.5
# total win provisory = -25.0
# total fundos provisory = 25.0
# in: /content/drive/MyDrive/Data_Football/Premiere_League/Predicts/Experiments/Summary_epl_2023_24.csv
# Jornada: 3
# total_funds_previousweek = 25.0
# bet_size = 2.5
# total win provisory = 5.75
# total fundos provisory = 30.75
# in: /content/drive/MyDrive/Data_Football/Premiere_League/Predicts/Experiments/Summary_epl_2023_24.csv
# Jornada: 4
# total_funds_previousweek = 30.76
# bet_size = 2.5
# total win provisory = -7.63
# total fundos provisory = 23.14
# in: /content/drive/MyDrive/Data_Football/Premiere_League/Predicts/Experiments/Summary_epl_2023_24.csv
# Jornada: 5
# total_funds_previousweek = 23.13
# bet_size = 2.5
# total win provisory = 16.8
# total fundos provisory = 39.93
# ...

# %% [markdown]
# Executar gráficos

# %%
# %run '/content/drive/MyDrive/Colab Notebooks/Generic_Graphs.ipynb'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# summary_path =/content/drive/MyDrive/Data_Football/Premiere_League/Predicts/Experiments/Summary_epl_2023_24.csv

# %% [markdown]
# Reset dos parametros

# %%
param_league = 'Bundesliga'
param_league_short = 'bd'
param_season = '_2023_24'
param_final_flag = True
param_odd_bet_limit = 1.2
param_number_matches_week = 9
param_itera_jornada = 10
