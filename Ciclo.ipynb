# %%
param_jornada = 0
jornada = 0
while jornada < 6:
  # %run '/content/drive/MyDrive/Colab Notebooks/Cópia de Untitled2.ipynb'
  print ('jornada = ' + str(jornada) )
  param_jornada = jornada

print ('fim')
# Out:
# jornada = 1
# jornada = 2
# jornada = 3
# jornada = 4
# jornada = 5
# jornada = 6
# fim
