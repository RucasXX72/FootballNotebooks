# %% [markdown]
# Mount do Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Fazer imports

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mtl

# %% [markdown]
# parametros

# %%
league = 'Bundesliga'
season = '_2022_23'

# %% [markdown]
# Definição de constantes

# %%
MAIN_PATH = '/content/drive/MyDrive/'
clean_path = MAIN_PATH + 'Data_Football/' + league + '/Clean/' + league + season + '_clean.csv'
stats_path = MAIN_PATH + 'Data_Football/' + league + '/Stats/' + league + season + '_stats.csv'

# %% [markdown]
# Invocar notebooks de funções

# %%
functions_path = MAIN_PATH + 'Colab Notebooks/Bet_Functions.ipynb'

# %run '{functions_path}'

# %% [markdown]
# Initi plot

# %%
mtl.rcParams['axes.grid'] = 'True'
mtl.rcParams['axes.spines.top'] = 'False'
mtl.rcParams['axes.spines.right'] = 'False'
mtl.rcParams['xtick.labelsize'] = 20
mtl.rcParams['ytick.labelsize'] = 20

# %% [markdown]
# incializar dataframe dp_lp (liga portugal)

# %%
df_lp= pd.read_csv(clean_path)

# %% [markdown]
# Criar lista com todas as equipas

# %%
home_teams = df_lp['HomeTeam'].unique()
away_teams = df_lp['AwayTeam'].unique()

all_teams = list(set(np.append(home_teams, away_teams)))

print(all_teams)
# Out:
# ['FCKOLN', 'DORTMUND', 'HOFFENHEIM', 'SCHALKE04', 'LEVERKUSEN', 'BOCHUM', 'UNIONBERLIN', 'RBLEIPZIG', 'MAINZ', 'STUTTGART', 'WERDERBREMEN', 'BAYERNMUNICH', "M'GLADBACH", 'AUGSBURG', 'WOLFSBURG', 'EINFRANKFURT', 'HERTHA', 'FREIBURG']

# %% [markdown]
# Calcular feature para todos os clubes (usa função calc_feats() definida em Bet_Functions.ipynb

# %%
all_teams_stats = []

for team in all_teams:
  team_stats = calc_feats(df_lp, team)
  all_teams_stats.append(team_stats)

print(all_teams_stats)
# Out:
# [{'team': 'FCKOLN', 'shots': 411, 'shots_ot': 159, 'shots_vs': 374, 'shots_ot_vs': 138, 'points': 42, 'form': 7}, {'team': 'DORTMUND', 'shots': 562, 'shots_ot': 233, 'shots_vs': 394, 'shots_ot_vs': 162, 'points': 71, 'form': 11}, {'team': 'HOFFENHEIM', 'shots': 410, 'shots_ot': 149, 'shots_vs': 487, 'shots_ot_vs': 169, 'points': 36, 'form': 7}, {'team': 'SCHALKE04', 'shots': 411, 'shots_ot': 132, 'shots_vs': 491, 'shots_ot_vs': 200, 'points': 31, 'form': 7}, {'team': 'LEVERKUSEN', 'shots': 428, 'shots_ot': 174, 'shots_vs': 380, 'shots_ot_vs': 154, 'points': 50, 'form': 3}, {'team': 'BOCHUM', 'shots': 392, 'shots_ot': 141, 'shots_vs': 524, 'shots_ot_vs': 202, 'points': 35, 'form': 8}, {'team': 'UNIONBERLIN', 'shots': 381, 'shots_ot': 127, 'shots_vs': 375, 'shots_ot_vs': 146, 'points': 62, 'form': 7}, {'team': 'RBLEIPZIG', 'shots': 506, 'shots_ot': 199, 'shots_vs': 324, 'shots_ot_vs': 111, 'points': 66, 'form': 15}, {'team': 'MAINZ', 'shots': 418, 'shots_ot': 161, 'shots_vs': 426, 'shots_ot_vs': 159, 'points': 46, 'form': 1}, {'team': 'STUTTGART', 'shots': 459, 'shots_ot': 150, 'shots_vs': 390, 'shots_ot_vs': 155, 'points': 33, 'form': 8}, {'team': 'WERDERBREMEN', 'shots': 355, 'shots_ot': 144, 'shots_vs': 478, 'shots_ot_vs': 187, 'points': 36, 'form': 1}, {'team': 'BAYERNMUNICH', 'shots': 633, 'shots_ot': 259, 'shots_vs': 312, 'shots_ot_vs': 112, 'points': 71, 'form': 12}, {'team': "M'GLADBACH", 'shots': 402, 'shots_ot': 178, 'shots_vs': 488, 'shots_ot_vs': 193, 'points': 43, 'form': 7}, {'team': 'AUGSBURG', 'shots': 361, 'shots_ot': 112, 'shots_vs': 540, 'shots_ot_vs': 208, 'points': 34, 'form': 4}, {'team': 'WOLFSBURG', 'shots': 401, 'shots_ot': 151, 'shots_vs': 465, 'shots_ot_vs': 150, 'points': 49, 'form': 6}, {'team': 'EINFRANKFURT', 'shots': 409, 'shots_ot': 148, 'shots_vs': 367, 'shots_ot_vs': 143, 'points': 50, 'form': 8}, {'team': 'HERTHA', 'shots': 379, 'shots_ot': 134, 'shots_vs': 472, 'shots_ot_vs': 177, 'points': 29, 'form': 7}, {'team': 'FREIBURG', 'shots': 420, 'shots_ot': 180, 'shots_vs': 451, 'shots_ot_vs': 165, 'points': 59, 'form': 6}]

# %% [markdown]
# Gravar em disco

# %%
df_all_stats= pd.DataFrame(all_teams_stats)
df_all_stats.to_csv(stats_path)
