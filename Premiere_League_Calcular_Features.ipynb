# %% [markdown]
# Fazer imports

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mtl

# %% [markdown]
# parametros

# %%
league = 'Premiere_League'
season = '_2022_23'

# %% [markdown]
# Definição de constantes

# %%
MAIN_PATH = '/content/drive/MyDrive/'
clean_path = MAIN_PATH + 'Data_Football/' + league + '/Clean/' + league + season + '_clean.csv'
stats_path = MAIN_PATH + 'Data_Football/' + league + '/Stats/' + league + season + '_stats.csv'

# %% [markdown]
# Invocar notebooks de funções

# %%
functions_path = MAIN_PATH + 'Colab Notebooks/Bet_Functions.ipynb'

# %run '{functions_path}'

# %% [markdown]
# Initi plot

# %%
mtl.rcParams['axes.grid'] = 'True'
mtl.rcParams['axes.spines.top'] = 'False'
mtl.rcParams['axes.spines.right'] = 'False'
mtl.rcParams['xtick.labelsize'] = 20
mtl.rcParams['ytick.labelsize'] = 20

# %% [markdown]
# incializar dataframe dp_lp (liga portugal)

# %%
df_lp= pd.read_csv(clean_path)

# %% [markdown]
# Criar lista com todas as equipas

# %%
home_teams = df_lp['HomeTeam'].unique()
away_teams = df_lp['AwayTeam'].unique()

all_teams = list(set(np.append(home_teams, away_teams)))

print(all_teams)
# Out:
# ['BRENTFORD', 'BOURNEMOUTH', 'ARSENAL', 'MANCITY', 'SOUTHAMPTON', 'LIVERPOOL', 'BRIGHTON', 'MANUNITED', 'EVERTON', 'LEEDS', 'NEWCASTLE', 'TOTTENHAM', 'FULHAM', 'LEICESTER', "NOTT'MFOREST", 'CRYSTALPALACE', 'WESTHAM', 'WOLVES', 'CHELSEA', 'ASTONVILLA']

# %% [markdown]
# Calcular feature para todos os clubes (usa função calc_feats() definida em Bet_Functions.ipynb

# %%
all_teams_stats = []

for team in all_teams:
  team_stats = calc_feats(df_lp, team)
  all_teams_stats.append(team_stats)

print(all_teams_stats)
# Out:
# [{'team': 'BRENTFORD', 'shots': 397, 'shots_ot': 162, 'shots_vs': 561, 'shots_ot_vs': 205, 'points': 59, 'form': 12}, {'team': 'BOURNEMOUTH', 'shots': 355, 'shots_ot': 133, 'shots_vs': 626, 'shots_ot_vs': 206, 'points': 39, 'form': 3}, {'team': 'ARSENAL', 'shots': 593, 'shots_ot': 204, 'shots_vs': 341, 'shots_ot_vs': 136, 'points': 84, 'form': 9}, {'team': 'MANCITY', 'shots': 603, 'shots_ot': 219, 'shots_vs': 293, 'shots_ot_vs': 96, 'points': 89, 'form': 10}, {'team': 'SOUTHAMPTON', 'shots': 417, 'shots_ot': 142, 'shots_vs': 525, 'shots_ot_vs': 158, 'points': 25, 'form': 1}, {'team': 'LIVERPOOL', 'shots': 605, 'shots_ot': 212, 'shots_vs': 369, 'shots_ot_vs': 160, 'points': 67, 'form': 11}, {'team': 'BRIGHTON', 'shots': 612, 'shots_ot': 231, 'shots_vs': 388, 'shots_ot_vs': 133, 'points': 62, 'form': 7}, {'team': 'MANUNITED', 'shots': 592, 'shots_ot': 214, 'shots_vs': 481, 'shots_ot_vs': 145, 'points': 75, 'form': 12}, {'team': 'EVERTON', 'shots': 429, 'shots_ot': 152, 'shots_vs': 575, 'shots_ot_vs': 193, 'points': 36, 'form': 8}, {'team': 'LEEDS', 'shots': 465, 'shots_ot': 145, 'shots_vs': 527, 'shots_ot_vs': 193, 'points': 31, 'form': 1}, {'team': 'NEWCASTLE', 'shots': 571, 'shots_ot': 197, 'shots_vs': 387, 'shots_ot_vs': 132, 'points': 71, 'form': 6}, {'team': 'TOTTENHAM', 'shots': 520, 'shots_ot': 200, 'shots_vs': 517, 'shots_ot_vs': 175, 'points': 60, 'form': 6}, {'team': 'FULHAM', 'shots': 429, 'shots_ot': 149, 'shots_vs': 505, 'shots_ot_vs': 200, 'points': 52, 'form': 7}, {'team': 'LEICESTER', 'shots': 417, 'shots_ot': 152, 'shots_vs': 572, 'shots_ot_vs': 178, 'points': 34, 'form': 5}, {'team': "NOTT'MFOREST", 'shots': 368, 'shots_ot': 118, 'shots_vs': 561, 'shots_ot_vs': 190, 'points': 38, 'form': 8}, {'team': 'CRYSTALPALACE', 'shots': 425, 'shots_ot': 136, 'shots_vs': 456, 'shots_ot_vs': 162, 'points': 45, 'form': 8}, {'team': 'WESTHAM', 'shots': 474, 'shots_ot': 145, 'shots_vs': 500, 'shots_ot_vs': 174, 'points': 40, 'form': 6}, {'team': 'WOLVES', 'shots': 413, 'shots_ot': 125, 'shots_vs': 555, 'shots_ot_vs': 182, 'points': 41, 'form': 4}, {'team': 'CHELSEA', 'shots': 484, 'shots_ot': 158, 'shots_vs': 438, 'shots_ot_vs': 168, 'points': 44, 'form': 5}, {'team': 'ASTONVILLA', 'shots': 431, 'shots_ot': 151, 'shots_vs': 423, 'shots_ot_vs': 159, 'points': 61, 'form': 7}]

# %% [markdown]
# Gravar em disco

# %%
df_all_stats= pd.DataFrame(all_teams_stats)
df_all_stats.to_csv(stats_path)
