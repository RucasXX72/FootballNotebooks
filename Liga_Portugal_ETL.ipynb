# %% [markdown]
# Imports de libraries

# %%
import os
import pandas as pd

# %% [markdown]
# Definição de Constantes

# %%
MAIN_PATH = '/content/drive/MyDrive/'

# %% [markdown]
# Invocar notebooks de funções e de constantes

# %%
functions_path = MAIN_PATH + 'Colab Notebooks/Bet_Functions.ipynb'

# %run '{functions_path}'

# %%
c = add_numbers(5, 6)
print(c)
# Out:
# 11

# %% [markdown]
# Extração do ficheiro clean

# %%
df=pd.read_csv(MAIN_PATH + 'Data_Football/Liga_Portugal/Raw/Liga_Portugal_2022_23.csv')
df_clean=df[["HomeTeam",	"AwayTeam",	"FTHG",	"FTAG",	"FTR",	"HTHG",	"HTAG",	"HTR",	"HS",	"AS",	"HST",	"AST",	"HF",	"AF",	"HC",	"AC",]].copy()

# %% [markdown]
# Limpar nomes dos clubes -Upper Case e limpar espaços

# %%
df_clean.loc[:, ['HomeTeam']] = df_clean["HomeTeam"].apply(str.upper).apply(lambda x: x.replace(' ', ''))
df_clean.loc[:, ['AwayTeam']] = df_clean["AwayTeam"].apply(str.upper).apply(lambda x: x.replace(' ', ''))

# %% [markdown]
# Copiar ficheiro final para a directoria clean

# %%
df_clean.to_csv(MAIN_PATH + 'Data_Football/Liga_Portugal/Clean/Liga_Portugal_2022_23_clean.csv')
df_clean.head(5)
# Out:
#      HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  HST  AST  \
# 0     BENFICA     AROUCA     4     0   H     3     0   H  20   3    6    2
# 1      RIOAVE     VIZELA     0     1   A     0     0   D   7  12    0    7
# 2     ESTORIL  FAMALICAO     2     0   H     2     0   H  10  15    5    5
# 3       PORTO   MARITIMO     5     1   H     3     0   H  22   9    7    3
# 4  SANTACLARA    CASAPIA     0     0   D     0     0   D   7  11    3    3
#
#    HF  AF  HC  AC
# 0   7   6   6   1
# 1  19  16   6   7
# 2  13  11   1   2
# 3  13  11   4   4
# 4  15  12   7   6
