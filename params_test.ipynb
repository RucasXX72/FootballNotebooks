# %% [markdown]
# Create params

# %%
#!pip install -I "phoebe>=2.3,<2.4"

# %%
import phoebe
from phoebe import u # units
import numpy as np

# %%
param_liga = phoebe.parameters.StringParameter(qualifier='liga',
                                          description='Liga a correr',
                                          value='lp')

# %% [markdown]
# Ler params

# %%
print(param_liga)
# Out:
# Parameter: liga
#                        Qualifier: liga
#                      Description: Liga a correr
#                            Value: lp
#                   Constrained by:
#                       Constrains: None
#                       Related to: None
